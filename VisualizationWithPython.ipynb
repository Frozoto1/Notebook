# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Matplotlib探索" data-toc-modified-id="Matplotlib探索-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Matplotlib探索</a></span><ul class="toc-item"><li><span><a href="#图形布局" data-toc-modified-id="图形布局-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>图形布局</a></span><ul class="toc-item"><li><span><a href="#共享x,y轴" data-toc-modified-id="共享x,y轴-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>共享x,y轴</a></span></li><li><span><a href="#图形间距调整" data-toc-modified-id="图形间距调整-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>图形间距调整</a></span></li><li><span><a href="#自定义图形布局" data-toc-modified-id="自定义图形布局-1.1.3"><span class="toc-item-num">1.1.3&nbsp;&nbsp;</span>自定义图形布局</a></span></li><li><span><a href="#关于修改字体" data-toc-modified-id="关于修改字体-1.1.4"><span class="toc-item-num">1.1.4&nbsp;&nbsp;</span>关于修改字体</a></span><ul class="toc-item"><li><span><a href="#Ex1设置全局的统一字体格式" data-toc-modified-id="Ex1设置全局的统一字体格式-1.1.4.1"><span class="toc-item-num">1.1.4.1&nbsp;&nbsp;</span>Ex1设置全局的统一字体格式</a></span></li><li><span><a href="#Ex2-另一种设置方式，附加将图形轴加粗" data-toc-modified-id="Ex2-另一种设置方式，附加将图形轴加粗-1.1.4.2"><span class="toc-item-num">1.1.4.2&nbsp;&nbsp;</span>Ex2 另一种设置方式，附加将图形轴加粗</a></span></li></ul></li><li><span><a href="#关于图例(legend)" data-toc-modified-id="关于图例(legend)-1.1.5"><span class="toc-item-num">1.1.5&nbsp;&nbsp;</span>关于图例(legend)</a></span></li><li><span><a href="#重新设置图例的颜色和标识" data-toc-modified-id="重新设置图例的颜色和标识-1.1.6"><span class="toc-item-num">1.1.6&nbsp;&nbsp;</span>重新设置图例的颜色和标识</a></span></li><li><span><a href="#一下为实际代码中的部分" data-toc-modified-id="一下为实际代码中的部分-1.1.7"><span class="toc-item-num">1.1.7&nbsp;&nbsp;</span>一下为实际代码中的部分</a></span></li><li><span><a href="#Annotation的使用" data-toc-modified-id="Annotation的使用-1.1.8"><span class="toc-item-num">1.1.8&nbsp;&nbsp;</span>Annotation的使用</a></span></li><li><span><a href="#图形中Text-commands" data-toc-modified-id="图形中Text-commands-1.1.9"><span class="toc-item-num">1.1.9&nbsp;&nbsp;</span>图形中Text commands</a></span></li><li><span><a href="#边框去除问题" data-toc-modified-id="边框去除问题-1.1.10"><span class="toc-item-num">1.1.10&nbsp;&nbsp;</span>边框去除问题</a></span></li></ul></li><li><span><a href="#常见图形的绘制" data-toc-modified-id="常见图形的绘制-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>常见图形的绘制</a></span><ul class="toc-item"><li><span><a href="#Boxplot" data-toc-modified-id="Boxplot-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Boxplot</a></span></li><li><span><a href="#热图" data-toc-modified-id="热图-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>热图</a></span></li><li><span><a href="#维恩图" data-toc-modified-id="维恩图-1.2.3"><span class="toc-item-num">1.2.3&nbsp;&nbsp;</span>维恩图</a></span><ul class="toc-item"><li><span><a href="#基本使用" data-toc-modified-id="基本使用-1.2.3.1"><span class="toc-item-num">1.2.3.1&nbsp;&nbsp;</span>基本使用</a></span></li><li><span><a href="#获取韦恩图中交集间数值" data-toc-modified-id="获取韦恩图中交集间数值-1.2.3.2"><span class="toc-item-num">1.2.3.2&nbsp;&nbsp;</span>获取韦恩图中交集间数值</a></span></li></ul></li><li><span><a href="#密度着色散点图" data-toc-modified-id="密度着色散点图-1.2.4"><span class="toc-item-num">1.2.4&nbsp;&nbsp;</span>密度着色散点图</a></span></li><li><span><a href="#水平与垂直线相关的图形" data-toc-modified-id="水平与垂直线相关的图形-1.2.5"><span class="toc-item-num">1.2.5&nbsp;&nbsp;</span>水平与垂直线相关的图形</a></span></li><li><span><a href="#染色体框架图(自定义)" data-toc-modified-id="染色体框架图(自定义)-1.2.6"><span class="toc-item-num">1.2.6&nbsp;&nbsp;</span>染色体框架图(自定义)</a></span></li><li><span><a href="#3D散点图" data-toc-modified-id="3D散点图-1.2.7"><span class="toc-item-num">1.2.7&nbsp;&nbsp;</span>3D散点图</a></span></li></ul></li></ul></li><li><span><a href="#Seaborn探索" data-toc-modified-id="Seaborn探索-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Seaborn探索</a></span></li><li><span><a href="#Altair探索" data-toc-modified-id="Altair探索-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Altair探索</a></span></li><li><span><a href="#Plotly探索" data-toc-modified-id="Plotly探索-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Plotly探索</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#表格绘制" data-toc-modified-id="表格绘制-4.0.1"><span class="toc-item-num">4.0.1&nbsp;&nbsp;</span>表格绘制</a></span></li><li><span><a href="#Bar-plot" data-toc-modified-id="Bar-plot-4.0.2"><span class="toc-item-num">4.0.2&nbsp;&nbsp;</span>Bar plot</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Matplotlib探索

# %% [markdown]
# ## 图形布局

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

# %%
from matplotlib_venn import venn2,venn2_circles
from matplotlib_venn import venn3,venn3_circles
import matplotlib.patches as mpatches

# %%
plt.figure(1,figsize=[6,6])
plt.subplot(121)
plt.plot()
plt.subplot(122)
plt.plot()
plt.axes([1, 0.1, .2, 0.8], facecolor='y')
#
plt.figure(2,figsize=[6,6])
plt.plot()
plt.axes([0.3, 0.6, .2, .2], facecolor='y')
plt.plot(np.random.randint(1,10,5),np.random.randint(1,10,5))
#
plt.figure(3,figsize=[6,6])
plt.subplot(311)
plt.plot()
#plt.subplot(312)
#plt.plot()
plt.subplot(313)
plt.plot()
#
fig = plt.figure(4,figsize=[3,3])
ax = fig.add_subplot(1,1,1)
ax.scatter([1,2,3],[1,2,3])
#
plt.show()

# %%
fig2 = plt.figure(figsize=[5,5],edgecolor='red')
plt.plot()
ax2 = fig2.add_axes([0.25, 0.2, 0.2, 0.2])
ax3 = fig2.add_axes([0.55, 0.2, 0.2, 0.2])
ax2.plot()
plt.show()

# %%
fig = plt.figure(1)
box = dict(facecolor='yellow', alpha=0.2)
ax1 = fig.add_subplot(211)
ax1.text(0.2,0.8,'hello')
#
ax1.yaxis.tick_right()
ax1.yaxis.set_label_position("right")
ax1.set_ylabel('right\nVer',fontsize=20,bbox=box,rotation=-90,labelpad=50)
#
ax2 = fig.add_subplot(212)
ax2.text(0.2,0.8,'hello')
brect = plt.Rectangle((0.2,0.25),0.2,0.5,color='red',fill=False)
ax2.add_patch(brect)
ylabel2 = ax2.set_ylabel('left\nHor',fontsize=20,rotation=0,labelpad=70,bbox=box)
#
plt.axes([0.6, 0.12, 0.2, 0.76])
plt.xlim([0,1])
plt.ylim([0,1])
plt.show()

# %% [markdown]
# ### 共享x,y轴

# %%
fig, ax = plt.subplots(2,3,sharex=True,sharey=True)
for i in range(2):
    for j in range(3):
        ax[i,j].text(0.5,0.5,str((i,j)),fontsize=18,ha='center')
plt.show()

# %% [markdown]
# ### 图形间距调整

# %% [markdown]
# [subplots_adjust相关参数](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplots_adjust.html)

# %%
fig = plt.figure(figsize=[5,5])
#
fig.add_subplot(221)
plt.text(0.5,0.4,'bottom=0.2,top=0.4',ha='center',fontsize=10)
#
fig.add_subplot(222)
plt.text(0.5,0.4,'bottom=0.2,top=0.4',ha='center',fontsize=10)
plt.subplots_adjust(wspace=0.2,hspace=0.2)
#
fig.add_subplot(223)
plt.text(0.5,0.4,'bottom=0.2,top=0.4',ha='center',fontsize=10)
plt.subplots_adjust(wspace=0.2,hspace=0.2)
#
fig.add_subplot(224)
plt.text(0.5,0.4,'bottom=0.2,top=0.4',ha='center',fontsize=10)
plt.subplots_adjust(wspace=0.2,hspace=0.2,bottom=0.2,top=0.4)
#
plt.savefig('test6.pdf')
plt.show()

# %% [markdown]
# 关于间距的其他有用的方法：
#
# [Tight Layout guide](https://matplotlib.org/users/tight_layout_guide.html)

# %% [markdown]
# ### 自定义图形布局

# %%
#实现不规则的多行多列子图
import matplotlib.pyplot as plt
grid = plt.GridSpec(2, 3, wspace=0.5, hspace=0.5)
plt.subplot(grid[0,0])
plt.subplot(grid[0,1:3])
plt.subplot(grid[1,0:2])
plt.subplot(grid[1,2])
plt.text(0.5,0.25,'hellooocarain',ha='center')
plt.show()

# %%
plt.figure(figsize=[18,6])
ax1 = plt.subplot2grid((4, 3), (0, 0), rowspan=4)
ax2 = plt.subplot2grid((4, 3), (0, 1))
ax3 = plt.subplot2grid((4, 3), (1, 1))
ax4 = plt.subplot2grid((4, 3), (2, 1))
ax5 = plt.subplot2grid((4, 3), (3, 1))
ax6 = plt.subplot2grid((4, 3), (0, 2),rowspan=4)
plt.show()

# %% [markdown]
# ### 关于修改字体

# %% [markdown]
# 一般字体的修改都可以通过fontsize属性设置，下面介绍全局字体的设置:
#
# [stackoverflow 问答](https://stackoverflow.com/questions/3899980/how-to-change-the-font-size-on-a-matplotlib-plot)

# %% [markdown]
# #### Ex1设置全局的统一字体格式

# %%
font = {'family' : 'Arial',
        'weight' : 'bold',
        'size'   : 22}
matplotlib.rc('font', **font)
fig,ax = plt.subplots(nrows=1,ncols=1,figsize=[8,8])
#针对某一特定的属性通过fontsize设置字体大小，优先于全局设置
ax.text(0.1,0.2,'Hello',fontsize=15)
#for tick in ax.yaxis.get_major_ticks():
#    tick.label1.set_fontweight('bold')
plt.show()

# %% [markdown]
# #### Ex2 另一种设置方式，附加将图形轴加粗

# %%
fig,ax = plt.subplots(ncols=1,nrows=1,figsize=[8,8])
ax.plot([1,2,3],[4,5,2],label='A')
ax.plot([1,2,3],[3,6,1],label='B')
#
SMALL_SIZE = 8
MEDIUM_SIZE = 15
BIGGER_SIZE = 20
#
plt.rc('font', size=MEDIUM_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('axes', linewidth=6)
plt.rc('xtick', labelsize=BIGGER_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=BIGGER_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title
#
ax.text(1.5,3.5,'Hello Oocarain')
ax.set_title('Test title')
ax.set_xlabel('Test_X_label')
ax.set_ylabel('Test_Y_label')
ax.legend()
plt.show()

# %% [markdown]
# 另一种将图形轴加粗的方案在这[Link](https://scipy-cookbook.readthedocs.io/items/Matplotlib_ThickAxes.html)

# %%
### Ex3 将全局字体的设置修改为默认
matplotlib.style.use('default')

# %% [markdown]
# ### 关于图例(legend)

# %% [markdown]
# ### 重新设置图例的颜色和标识
# ### 一下为实际代码中的部分
# ```python3
# fig,axes = plt.subplots(ncols=2,nrows=1,figsize=[10,4])
# p1 = axes[0].barh([0,1,2], mCHHIsland[['Hyper_wtle25']].values.reshape(1,3)[0],color='blue',align='center')
# p2 = axes[0].barh([0,1,2], mCHHIsland[['Hyper_wtgt25']].values.reshape(1,3)[0]+
#          mCHHIsland[['Hyper_wtle25']].values.reshape(1,3)[0],color='red',align='center',alpha=0.3)
# #
# acolor_path = mpatches.Patch(color='#5500ad',label='<=25%')
# bcolor_path = mpatches.Patch(color='#ffb3b2',label='>25%')
# plt.legend((p1[0],p2[0]),('<=25%','>25%'),frameon=False,fontsize='x-large',ncol=2,
#            bbox_to_anchor=(0.5, 1),handles=[acolor_path,bcolor_path])
# ```

# %% [markdown]
# ### Annotation的使用

# %% [markdown]
# 首先可以参考[官方文档](https://matplotlib.org/users/annotations_guide.html)

# %% [markdown]
# - 一些使用示例

# %%
fig,ax = plt.subplots(nrows=2,ncols=2,figsize=[13,13])
fs=15
#垂直花括号，xytext()中y坐标需要调整以使花括号垂直x轴
ax[0,0].annotate('90%', xy=(1.05, 0.2), xytext=(1.2, 0.165), xycoords='axes fraction', 
            fontsize=fs*1.5,ha='center',va='bottom',
            arrowprops=dict(arrowstyle='-[, widthB=3.0, lengthB=0.5', lw=2.0))
# 水平花括号
ax[0,1].annotate('Good', xy=(0.4, 0.1), xytext=(0.4, 0.15), xycoords='axes fraction', 
            fontsize=fs*1.5,ha='center',va='bottom',
            arrowprops=dict(arrowstyle='-[, widthB=2.7, lengthB=0.5', lw=2.0))
#
ax[1,0].annotate("", xy=(1, 0.05), xytext=(0, 0.05),arrowprops={'width':1})
#

ax[1,1].annotate("START",
            xy=(0.2, 0.2), xycoords='data',
            xytext=(0.8, 0.8), textcoords='data',
            size=20, va="center", ha="center",
            arrowprops=dict(arrowstyle="simple",
                            connectionstyle="arc3,rad=-0.2"), 
            )
ax[1,1].text(0.2,0.2,'END',ha='right',va='top',fontsize=20)
#
plt.subplots_adjust(wspace=0.4)
plt.show()
#补充：
#bbox=dict(boxstyle='square', fc='white') 这个参数可以为文字添加边框

# %% [markdown]
# > 关于上图第四个子图中connectionstyle="arc3,rad=-0.2"参数的解释(图片来自官方文档)：
#
# ![](https://i.loli.net/2018/11/19/5bf273024e31e.png)

# %% [markdown]
# > 注意：
#
# ```python3
# axes.flatten()[i].annotate("", xy=(380, -0.5), xytext=(0, -0.5),arrowprops={'arrowstyle':"->"})
# #第一个参数为箭尾注释,xy为箭头坐标，xytext为箭尾坐标
# #注意当使用arrowstyle属性的时候其他的arrowprops属性将被禁用
# axes.flatten()[i].annotate("", xy=(380, -0.3), xytext=(0, -0.3),arrowprops={'width':1})
# ```

# %% [markdown]
# ### 图形中Text commands

# %% [markdown]
# - 以下来自[官方示例](https://matplotlib.org/gallery/pyplots/text_commands.html#sphx-glr-gallery-pyplots-text-commands-py)

# %%
fig = plt.figure(figsize=[6,6])
fig.suptitle('bold figure suptitle', fontsize=14, fontweight='bold')

ax = fig.add_subplot(111)
fig.subplots_adjust(top=0.85)
ax.set_title('axes title')

ax.set_xlabel('xlabel')
ax.set_ylabel('ylabel')

ax.text(3, 8, 'boxed italics text in data coords', style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})

ax.text(2, 6, r'an equation: $E=mc^2$', fontsize=15)

ax.text(3, 2, 'unicode: Institut f\374r Festk\366rperphysik')

ax.text(0.95, 0.01, 'colored text in axes coords',
        verticalalignment='bottom', horizontalalignment='right',
        transform=ax.transAxes,
        color='green', fontsize=15)


ax.plot([2], [1], 'o')
ax.annotate('annotate', xy=(2, 1), xytext=(3, 4),
            arrowprops=dict(facecolor='black', shrink=0.05))

ax.axis([0, 10, 0, 10])

plt.show()

# %% [markdown]
# - 另外一个[官方示例](https://matplotlib.org/users/annotations_guide.html)

# %%
fig = plt.figure(1, figsize=(5,5))
fig.clf()

ax = fig.add_subplot(111)
ax.set_aspect(1)

x1 = -1 + np.random.randn(100)
y1 = -1 + np.random.randn(100)
x2 = 1. + np.random.randn(100)
y2 = 1. + np.random.randn(100)

ax.scatter(x1, y1, color="r")
ax.scatter(x2, y2, color="g")

bbox_props = dict(boxstyle="round", fc="w", ec="0.5", alpha=0.9)
ax.text(-2, -2, "Sample A", ha="center", va="center", size=20,
        bbox=bbox_props)
ax.text(2, 2, "Sample B", ha="center", va="center", size=20,
        bbox=bbox_props)


bbox_props = dict(boxstyle="rarrow", fc=(0.8,0.9,0.9), ec="b", lw=2)
t = ax.text(0, 0, "Direction", ha="center", va="center", rotation=45,
            size=15,
            bbox=bbox_props)

#通过下面pad参数可以使bbox等比例放大或缩小
bb = t.get_bbox_patch()
bb.set_boxstyle("rarrow", pad=0.6)

ax.set_xlim(-4, 4)
ax.set_ylim(-4, 4)

plt.draw()
plt.show()

# %% [markdown]
# ### 边框去除问题

# %%
fig, ax = plt.subplots(figsize=[4,4])
ax.plot([1,2],[3,4])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
#ax.spines['bottom'].set_visible(False)
#ax.spines['left'].set_visible(False)
plt.show()

# %%
fig, ax = plt.subplots(figsize=[4,4])
ax.plot([1,2],[3,4])
plt.axis('off')
plt.show()

# %% [markdown]
# > `plt.axis('off')`是关闭坐标轴，也就是之后坐标轴相关的属性将无法设置，而`ax.spines['top'].set_visible(False)`方法
# > 只是将坐标轴不显示

# %% [markdown]
# ## 常见图形的绘制

# %% [markdown]
# ### Boxplot

# %% [markdown]
# > 关于Box Plot
#
# [box plot](http://www.physics.csbsju.edu/stats/box2.html)
#
# > 关于Notched Box Plots
#
# [Notched Box Plots](https://sites.google.com/site/davidsstatistics/home/notched-box-plots)
#
# > Python3 matplotlib 实现Box plot 与 Notched Box plots
#
# [Boxplot drawer function](https://matplotlib.org/devdocs/gallery/statistics/bxp.html#sphx-glr-gallery-statistics-bxp-py)
#
# > 其他补充材料
#
# [置信区间的Bootstrap方法参考1](http://blog.sciencenet.cn/blog-255662-523462.html)
#
# [置信区间的Bootstrap方法参考2](http://www.dummies.com/education/science/biology/the-bootstrap-method-for-standard-errors-and-confidence-intervals/)
#
# [matplotlib.cbook.boxplot_stats()函数参数说明](https://matplotlib.org/api/cbook_api.html)

# %% [markdown]
# ### 热图

# %%
x = np.linspace(0, 6)
y = np.linspace(0, 3)[:, np.newaxis]
z = 10 * np.cos(x ** 2) * np.exp(-y)

# %%
z
# Out:
# array([[10.        ,  9.99887596,  9.98202038, ..., -1.34071692,
#         -9.99929039, -1.2796369 ],
#        [ 9.40612058,  9.4050633 ,  9.38920874, ..., -1.2610945 ,
#         -9.40545311, -1.20364189],
#        [ 8.84751044,  8.84651594,  8.83160295, ..., -1.1862007 ,
#         -8.84688261, -1.13216008],
#        ...,
#        [ 0.56272404,  0.56266079,  0.56171229, ..., -0.07544536,
#         -0.56268411, -0.07200824],
#        [ 0.52930502,  0.52924552,  0.52835335, ..., -0.07096482,
#         -0.52926746, -0.06773182],
#        [ 0.49787068,  0.49781472,  0.49697553, ..., -0.06675036,
#         -0.49783535, -0.06370937]])

# %%
plt.imshow(z,cmap='RdYlBu_r')
plt.colorbar()
plt.show()

# %% [markdown]
# 注：关于配色[color example code: colormaps_reference.py](https://matplotlib.org/examples/color/colormaps_reference.html)

# %% [markdown]
# ### 维恩图

# %% [markdown]
# #### 基本使用

# %%
plt.figure(figsize=(4,4))
v = venn3(subsets=(5, 1, 2, 1, 4, 1,3), set_labels = ('A', 'B', 'C'))
#设置一个ven颜色
v.get_patch_by_id('A').set_color('white')
#设置一个透明度
v.get_patch_by_id('B').set_alpha(0.8)
#修改某标签的文本
#v.get_label_by_id('A').set_text('Set "A"')
#点线修饰边缘(点线circle的使用)
c = venn3_circles(subsets=(5, 1, 2, 1, 4, 1, 3), linestyle='dashed')
#c[0].set_lw(1.0)
#c[0].set_ls('dotted')
# 设置label字体大小
for text in v.set_labels:
    text.set_fontsize(20)
# 设置venny图内字体大小
for text in v.subset_labels:
    text.set_fontsize(25) 
# 单独设置某个标签的大小
#v.get_label_by_id('A').set_fontsize(22)
# 设置A标签的位置
labelA = v.get_label_by_id('A')
labelA.set_x(labelA.get_position()[0]-0.2) #x方向
labelA.set_y(labelA.get_position()[1]-0.2) #y方向
    
#添加标记注释
#plt.annotate('Unknown set', xy=v.get_label_by_id('100').get_position() - np.array([0, 0.05]), xytext=(-70,-70),
#             ha='center', textcoords='offset points', bbox=dict(boxstyle='round,pad=0.5', fc='gray', alpha=0.1),
#             arrowprops=dict(arrowstyle='->', connectionstyle='arc3,rad=0.5',color='gray'))
plt.title('Test a venny',fontsize=20)
plt.show()

# %%
figure, axes = plt.subplots(ncols=2,nrows=2,figsize=[8,8])
a = venn2(subsets={'10': 1, '01': 1, '11': 1}, set_labels = ('A', 'B'), ax=axes[0][0])
labelA = a.get_label_by_id('A')
labelA.set_x(labelA.get_position()[0]-0.2) #x方向
labelA.set_y(labelA.get_position()[1]-0.2) #y方向
venn2_circles((1, 2, 3), ax=axes[0][1])
venn3(subsets=(1, 1, 1, 1, 1, 1, 1), set_labels = ('A', 'B', 'C'), ax=axes[1][0])
venn3_circles({'001': 10, '100': 20, '010': 21, '110': 13, '011': 14}, ax=axes[1][1])
plt.show()

# %%
figure, axe = plt.subplots(ncols=1,nrows=1,figsize=[8,8])
v2 = venn2((1, 2, 3), ax=axe,set_labels = ('A', 'B'))
for text in v2.set_labels:
    text.set_fontsize(25)
for text in v2.subset_labels:
    text.set_fontsize(25) 
# 设置A标签的位置
labelA = v2.get_label_by_id('A')
labelA.set_x(labelA.get_position()[0]-0.5) #x方向
labelA.set_y(labelA.get_position()[1]+0.54) #y方向
# 设置B标签的位置
labelB = v2.get_label_by_id('B')
labelB.set_x(labelB.get_position()[0]+0.56) #x方向
labelB.set_y(labelB.get_position()[1]+0.6) #y方向
#
venn2_circles(subsets=[1,2,3])
plt.show()

# %%
figure, axe = plt.subplots(ncols=1,nrows=1,figsize=[8,8])
v3 = venn3((1, 2, 3,4,5,6,7), ax=axe,set_labels = ('A', 'B','C'))
for text in v3.set_labels:
    text.set_fontsize(25)
for text in v3.subset_labels:
    text.set_fontsize(25) 
# 设置A标签的位置
#labelA = v2.get_label_by_id('A')
#labelA.set_x(labelA.get_position()[0]-0.5) #x方向
#labelA.set_y(labelA.get_position()[1]+0.54) #y方向
# 设置B标签的位置
#labelB = v2.get_label_by_id('B')
#labelB.set_x(labelB.get_position()[0]+0.56) #x方向
#labelB.set_y(labelB.get_position()[1]+0.6) #y方向
#
venn3_circles(subsets=[1, 2, 3,4,5,6,7])
plt.show()

# %%
figure, axe = plt.subplots(ncols=1,nrows=1,figsize=[8,8])
v3 = venn3([set([1,2,3,4,5,6]),set([2,3,7,8,9]),set([3,7,10,12])], ax=axe,set_labels = ('A', 'B','C'))
for text in v3.set_labels:
    text.set_fontsize(25)
for text in v3.subset_labels:
    text.set_fontsize(25) 
venn3_circles(subsets=[4,2,1,2,0,1,1])
plt.show()

# %% [markdown]
# #### 获取韦恩图中交集间数值

# %%
figure, axe = plt.subplots(ncols=1,nrows=1,figsize=[8,8])
#
A = set(['a','b','c','g','h','i','j','k','l','m','n','o'])
B = set(['a','b','c','p','q','r','s','t','u','d','e','f'])
C = set(['a','g','h','i','j','d','e','f','v','w','x','y','z','1','2'])
#
v3 = venn3([A, B, C], ('A', 'B', 'C'),ax=axe)
#
for text in v3.set_labels:
    text.set_fontsize(25)
for text in v3.subset_labels:
    text.set_fontsize(25) 
plt.show()

# %%
#通过get_text()属性获取交集的值
a = v3.get_label_by_id('001').get_text()
b = v3.get_label_by_id('010').get_text()
c = v3.get_label_by_id('100').get_text()
d = v3.get_label_by_id('101').get_text()
e = v3.get_label_by_id('011').get_text()
f = v3.get_label_by_id('110').get_text()
g =  v3.get_label_by_id('111').get_text()
print('{}\t{}\t{}\t{}\t{}\t{}\t{}'.format(a,b,c,d,e,f,g))
# Out:
# 7	6	5	4	3	2	1

# %% [markdown]
# > 下面附上交集各部分的表征值：
#
# ![](https://i.loli.net/2018/11/19/5bf276c52fecd.png)

# %% [markdown]
# ### 密度着色散点图

# %%
from scipy.stats import gaussian_kde

# %%
# Generate fake data
x = np.random.normal(size=1000)
y = x * 3 + np.random.normal(size=1000)

# Calculate the point density
xy = np.vstack([x,y])
z = gaussian_kde(xy)(xy)

fig, ax = plt.subplots(figsize=[6,6])
ax.scatter(x, y, c=z, s=100, edgecolor='')
plt.show()

# %%
#以密度的顺序绘制点，只需按z值对它们进行排序即可
# Generate fake data
x = np.random.normal(size=1000)
y = x * 3 + np.random.normal(size=1000)

# Calculate the point density
xy = np.vstack([x,y])
### 注意：数据点非常多的时候gaussuan_kde()的计算非常慢
z = gaussian_kde(xy)(xy)

# Sort the points by density, so that the densest points are plotted last
idx = z.argsort()
x, y, z = x[idx], y[idx], z[idx]

fig, ax = plt.subplots(figsize=[6,6])
ax.scatter(x, y, c=z, s=20, edgecolor='')
plt.show()

# %% [markdown]
# ### 水平与垂直线相关的图形

# %%
fig,axes = plt.subplots(ncols=3,nrows=1,figsize=[6,12])
#
markerline, stemlines, baseline = axes[0].stem([2,4,6], [3,5,7], '-')
plt.setp(markerline,'color','orange')
plt.setp(stemlines,'color','cyan','lw',3)
plt.setp(baseline,'color','red')
axes[0].set_xlim(1,10)
axes[0].set_ylim(1,10)
#
axes[1].vlines([1,3,5,7,8,9], 3, [2]*6, color='orange')
axes[2].hlines(np.array([2,3,5,7,8,9,10]), 2, [6]*7, color='red',lw=1)
axes[1].set_xlim(1,10)
axes[1].set_ylim(1,10)
axes[2].set_xlim(1,10)
axes[2].set_ylim(1,10)
plt.show()

# %% [markdown]
# ### 染色体框架图(自定义)

# %%
AT_Chr1 = 30427671
AT_Chr2 = 19698289
AT_Chr3 = 23459830
AT_Chr4 = 18585056
AT_Chr5 = 26975502
AT_chr_len = [AT_Chr1,AT_Chr2,AT_Chr3,AT_Chr4,AT_Chr5]

# %%
AT_Chr1_percen_spos = 10653718
AT_Chr1_percen_epos = 18028851
AT_Chr1_percen_len = AT_Chr1_percen_epos - AT_Chr1_percen_spos
#
AT_Chr2_percen_spos = 1447413
AT_Chr2_percen_epos = 7633697
AT_Chr2_percen_len = AT_Chr2_percen_epos - AT_Chr2_percen_spos
#
AT_Chr3_percen_spos = 10596181
AT_Chr3_percen_epos = 17211861
AT_Chr3_percen_len = AT_Chr3_percen_epos - AT_Chr3_percen_spos
#
AT_Chr4_percen_spos = 1782389
AT_Chr4_percen_epos = 7340897
AT_Chr4_percen_len = AT_Chr4_percen_epos - AT_Chr4_percen_spos
#
AT_Chr5_percen_spos = 10488859
AT_Chr5_percen_epos = 15466565
AT_Chr5_percen_len = AT_Chr5_percen_epos - AT_Chr5_percen_spos
#
AT_percen = [[AT_Chr1_percen_spos,AT_Chr1_percen_len],[AT_Chr2_percen_spos,AT_Chr2_percen_len],
             [AT_Chr3_percen_spos,AT_Chr3_percen_len],[AT_Chr4_percen_spos,AT_Chr4_percen_len],
             [AT_Chr5_percen_spos,AT_Chr5_percen_len]]

# %%
#
f, axes = plt.subplots(1, 5, figsize=(6, 12))
#
for i in range(5):
    axes[i].set_ylim([-100000,max(AT_chr_len)+100000])
    axes[i].set_xlim([0,1])
    #plt.Rectangle()四个位置参数的含义分别是绘制方块左下角顶点x坐标,左下角顶点y坐标,方块长度，方块高度
    arect_chr = plt.Rectangle((0.2,1),0.6,AT_chr_len[i],color='black',fill=False,lw=3)
    axes[i].add_patch(arect_chr)
    #
    arect_percen = plt.Rectangle((0.2,AT_percen[i][0]),0.6,AT_percen[i][1],color='red',fill=False,lw=3)
    axes[i].add_patch(arect_percen)
    #
    axes[i].set_xlabel('Chr'+str(i+1),fontsize=20)
    #核心绘图区
    
    #
    #axes[i].axis('off')
    axes[i].spines['top'].set_visible(False)
    axes[i].spines['bottom'].set_visible(False)
    axes[i].spines['left'].set_visible(False)
    axes[i].spines['right'].set_visible(False)
    axes[i].set_yticks([])
    axes[i].set_xticks([])
plt.show()

# %% [markdown]
# ### 3D散点图

# %%
from mpl_toolkits.mplot3d import Axes3D

data = np.random.randint(0, 255, size=[40, 40, 40])

x, y, z = data[0], data[1], data[2]
ax = plt.subplot(111, projection='3d')  # 创建一个三维的绘图工程
#  将数据点分成三部分画，在颜色上有区分度
ax.scatter(x, y, z, c='r')  # 绘制数据点

ax.set_zlabel('Z')
ax.set_ylabel('Y')
ax.set_xlabel('X')
plt.show()

# %% [markdown]
# # Seaborn探索

# %% [markdown]
# # Altair探索

# %%
import altair as alt
from altair.expr import datum
from vega_datasets import data
alt.renderers.enable('notebook')
# Out:
# RendererRegistry.enable('notebook')

# %%
source = data.disasters.url

alt.Chart(source).mark_circle(
    opacity=0.8,
    stroke='black',
    strokeWidth=1
).encode(
    alt.X('Year:O', axis=alt.Axis(labelAngle=0)),
    alt.Y('Entity:N'),
    alt.Size('Deaths:Q',
        scale=alt.Scale(range=[0, 5000]),
        legend=alt.Legend(title='Annual Global Deaths')
    ),
alt.Color('Entity:N', legend=None)
).properties(
    width=480,
    height=350
).transform_filter(
    datum.Entity != 'All natural disasters'
)

# %% [markdown]
# # Plotly探索

# %%
import plotly

# %%
plotly.__version__
# Out:
# '3.1.1'

# %%
import plotly.plotly as py
import plotly.graph_objs as go
from plotly import tools
tools.set_credentials_file(username='oocarain', api_key='GMV6c1aFsf3SKSD1JOlA')

# %%
import plotly.figure_factory as ff

# %% [markdown]
# ### 表格绘制

# %%
df = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/school_earnings.csv")
#table = ff.create_table(df)
table = ff.create_table(df)
py.iplot(table,filename='jupyter-table1')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~oocarain/3.embed" height="710px" width="100%"></iframe>

# %% [markdown]
# ### Bar plot

# %%
data = [go.Bar(x=df.School,
            y=df.Gap)]

py.iplot(data, filename='jupyter-basic_bar')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~oocarain/5.embed" height="525px" width="100%"></iframe>

# %%
trace_women = go.Bar(x=df.School,
                  y=df.Women,
                  name='Women',
                  marker=dict(color='#ffcdd2'))

trace_men = go.Bar(x=df.School,
                y=df.Men,
                name='Men',
                marker=dict(color='#A2D5F2'))

trace_gap = go.Bar(x=df.School,
                y=df.Gap,
                name='Gap',
                marker=dict(color='#59606D'))

data = [trace_women, trace_men, trace_gap]

layout = go.Layout(title="Average Earnings for Graduates",
                xaxis=dict(title='School'),
                yaxis=dict(title='Salary (in thousands)'))

fig = go.Figure(data=data, layout=layout)

py.iplot(fig, filename='jupyter-styled_bar')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~oocarain/7.embed" height="525px" width="100%"></iframe>

# %%
#
trace1 = go.Bar(
    y=['giraffes', 'orangutans', 'monkeys'],
    x=[20, 14, 23],
    name='SF Zoo',
    orientation = 'h',
    marker = dict(
        color = 'rgba(246, 78, 139, 0.6)',
        line = dict(
            color = 'rgba(246, 78, 139, 1.0)',
            width = 3)
    )
)
trace2 = go.Bar(
    y=['giraffes', 'orangutans', 'monkeys'],
    x=[12, 18, 29],
    name='LA Zoo',
    orientation = 'h',
    marker = dict(
        color = 'rgba(58, 71, 80, 0.6)',
        line = dict(
            color = 'rgba(58, 71, 80, 1.0)',
            width = 3)
    )
)

data = [trace1, trace2]
layout = go.Layout(
    barmode='stack'
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='marker-h-bar',dpi=300)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~oocarain/1.embed" height="525px" width="100%"></iframe>

# %%
circle_x = [0.1,0.3,0.4,0.6,0.9]
circle_num = [2,5,2,1,6]

# %%
def circles(x, y, s, c='b', vmin=None, vmax=None, **kwargs):
    """
    Make a scatter of circles plot of x vs y, where x and y are sequence 
    like objects of the same lengths. The size of circles are in data scale.

    Parameters
    ----------
    x,y : scalar or array_like, shape (n, )
        Input data
    s : scalar or array_like, shape (n, ) 
        Radius of circle in data unit.
    c : color or sequence of color, optional, default : 'b'
        `c` can be a single color format string, or a sequence of color
        specifications of length `N`, or a sequence of `N` numbers to be
        mapped to colors using the `cmap` and `norm` specified via kwargs.
        Note that `c` should not be a single numeric RGB or RGBA sequence 
        because that is indistinguishable from an array of values
        to be colormapped. (If you insist, use `color` instead.)  
        `c` can be a 2-D array in which the rows are RGB or RGBA, however. 
    vmin, vmax : scalar, optional, default: None
        `vmin` and `vmax` are used in conjunction with `norm` to normalize
        luminance data.  If either are `None`, the min and max of the
        color array is used.
    kwargs : `~matplotlib.collections.Collection` properties
        Eg. alpha, edgecolor(ec), facecolor(fc), linewidth(lw), linestyle(ls), 
        norm, cmap, transform, etc.

    Returns
    -------
    paths : `~matplotlib.collections.PathCollection`

    Examples
    --------
    a = np.arange(11)
    circles(a, a, a*0.2, c=a, alpha=0.5, edgecolor='none')
    plt.colorbar()

    License
    --------
    This code is under [The BSD 3-Clause License]
    (http://opensource.org/licenses/BSD-3-Clause)
    """
    #import numpy as np
    #import matplotlib.pyplot as plt
    from matplotlib.patches import Circle
    from matplotlib.collections import PatchCollection

    if np.isscalar(c):
        kwargs.setdefault('color', c)
        c = None
    if 'fc' in kwargs: kwargs.setdefault('facecolor', kwargs.pop('fc'))
    if 'ec' in kwargs: kwargs.setdefault('edgecolor', kwargs.pop('ec'))
    if 'ls' in kwargs: kwargs.setdefault('linestyle', kwargs.pop('ls'))
    if 'lw' in kwargs: kwargs.setdefault('linewidth', kwargs.pop('lw'))

    patches = [Circle((x_, y_), s_) for x_, y_, s_ in np.broadcast(x, y, s)]
    collection = PatchCollection(patches, **kwargs)
    if c is not None:
        collection.set_array(np.asarray(c))
        collection.set_clim(vmin, vmax)

    ax = plt.gca()
    ax.add_collection(collection)
    ax.autoscale_view()
    if c is not None:
        plt.sci(collection)
    return collection

# %%
plt.figure(1,figsize=[8,8])
ax = plt.subplot(aspect='equal')
circles(circle_x, [1]*5, np.array(circle_num)*0.02, c='orange', alpha=0.5, ec='none')
out = circles(circle_x, [1.5]*5, np.array(circle_num)*0.02, c='orange', alpha=0.5, ec='none')

plt.xlim(0,2)
plt.ylim(0,2)
#
plt.figure(2,figsize=[8,8])
ax = plt.subplot(aspect='equal')
plt.xlim(0,2)
plt.ylim(0,2)
plt.plot()
plt.show()
